# %% [markdown]
# <a href="https://colab.research.google.com/github/fmathews11/College_Basketball_Functions/blob/main/Getting_Schedules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kenpompy
# !pip install mechanicalsoup
import mechanicalsoup,pandas as pd,numpy as np, warnings,seaborn as sns, matplotlib.pyplot as plt, requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
ids = pd.read_csv('https://raw.githubusercontent.com/fmathews11/College_Basketball_Functions/main/ids.csv')
ids
# Out:
#                team    id                        link
# 0    Abil Christian  2000  abilene-christian-wildcats
# 1         Air Force  2005           air-force-falcons
# 2             Akron  2006                  akron-zips
# 3           Alabama   333        alabama-crimson-tide
# 4       Alabama A&M  2010         alabama-am-bulldogs
# ..              ...   ...                         ...
# 356    Wright State  2750           wright-st-raiders
# 357         Wyoming  2751             wyoming-cowboys
# 358          Xavier  2752           xavier-musketeers
# 359            Yale    43               yale-bulldogs
# 360   Youngstown St  2754      youngstown-st-penguins
#
# [361 rows x 3 columns]

# %%
current_season = '2021-22'
season = current_season
team = "Rutgers"
url = "https://www.espn.com/mens-college-basketball/team/schedule/_/id/"

if season == current_season:
  team_link = ids[ids.team == team].link.item()
  team_id = str(ids[ids.team == team].id.item())
  url = url + team_id + "/" + team_link
  print(url)
# Out:
# https://www.espn.com/mens-college-basketball/team/schedule/_/id/164/rutgers-scarlet-knights

# %%
browser = mechanicalsoup.StatefulBrowser()
current_season = '2021-22'
season = current_season
team = "Clemson"
url = "https://www.espn.com/mens-college-basketball/team/schedule/_/id/"
if season == current_season:
  team_link = ids[ids.team == team].link.item()
  team_id = str(ids[ids.team == team].id.item())
  url = url + team_id + "/" + team_link
browser.open(url)
test = str(browser.get_current_page())
test.split('gameID')[0]
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n<meta charset="utf-8"/>\n<!-- ESPNFITT | da76f8efff9d | 5433 | 1e9377d30dcfee172e235181f1d1f886debb8b09 | Fri, 18 Feb 2022 13:38:46 GMT -->\n<script async="" src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js" type="text/javascript"></script>\n<script type="text/javascript">\n        ;(function(){\n            function gc(n){n=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return n?n[2]:null}function sc(n){document.cookie=n}function smpl(n){n/=100;return!!n&&Math.random()<=n}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;\n            _nr && window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true}};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h=" ...

# %%
r = requests.get(url).text
r
# Out:
# '\n        <!doctype html>\n        <html lang="en">\n            <head>\n                <meta charSet="utf-8" />\n\n                <!-- ESPNFITT | d3cdba167cc4 | 5433 | 1e9377d30dcfee172e235181f1d1f886debb8b09 | Fri, 18 Feb 2022 13:39:44 GMT -->\n                <script type="text/javascript" src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js" async></script>\n                <script type="text/javascript">\n        ;(function(){\n            function gc(n){n=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return n?n[2]:null}function sc(n){document.cookie=n}function smpl(n){n/=100;return!!n&&Math.random()<=n}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;\n            _nr && window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true}};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings" ...

# %%
test = r.split('gameId')
for i in range (1,len(df)+1):
  print(test[i][1:11])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-05cff0fecc1a> in <module>()
#       1 test = r.split('gameId')
# ----> 2 for i in range (1,len(df)+1):
#       3   print(test[i][1:11])
#
# NameError: name 'df' is not defined

# %%
dfs = pd.read_html(url)
df= dfs[0]
df.columns = df.iloc[1,:].tolist()
things_to_avoid = ['Canceled','Postponed']
df = df[~df.RESULT.isin(things_to_avoid)]
df = df.iloc[2:,[0,1]]
df = df[df.DATE != 'DATE']
df['GAME_ID'] = [test[i][1:10] for i in range(1,len(df)+1)]
df
# Out:
#            DATE                 OPPONENT    GAME_ID
# 2    Tue, Nov 9          vs Presbyterian  401369925
# 3   Fri, Nov 12               vs Wofford  401369926
# 4   Mon, Nov 15                vs Bryant  401369927
# 5   Thu, Nov 18              vs Temple *  401365886
# 6   Fri, Nov 19  vs 22 St. Bonaventure *  401377051
# 7   Sun, Nov 21       vs West Virginia *  401377054
# 8   Fri, Nov 26   vs Charleston Southern  401369928
# 9   Tue, Nov 30                @ Rutgers  401369929
# 10   Sat, Dec 4                  @ Miami  401370078
# 11  Sat, Dec 11               vs Drake *  401369930
# 12  Tue, Dec 14            vs Miami (OH)  401369931
# 13  Sat, Dec 18        vs South Carolina  401369932
# 14  Wed, Dec 22               @ Virginia  401370045
# 16   Tue, Jan 4              vs Virginia  401369934
# 17   Sat, Jan 8               @ NC State  401370104
# 18  Wed, Jan 12             @ Notre Dame  401369970
# 19  Sat, Jan 15        vs Boston College  401369935
# 20  Tue, Jan 18               @ Syracuse  401370011
# 21  Sat, Jan 22            vs Pittsburgh  401369936
# 22  Tue, Jan 25                 @ 9 Duke  401369865
# 23   Wed, Feb 2         vs Florida State  401369937
# 24   Sat, Feb 5           @ Georgia Tech  401369905
# 25   Tue, Feb 8        vs North Carolina  401369938
# 26  Thu, Feb 10                vs 7 Duke  401408050
# 27  Sat, Feb 12            vs Notre Dame  401369939
# 28  Tue, Feb 15          @ Florida State  401369886
# 30  Sat, Feb 19             @ Louisville  401370120
# 31  Wed, Feb 23           vs Wake Forest  401369940
# 32  Sat, Feb 26         @ Boston College  401369923
# 33   Wed, Mar 2          vs Georgia Tech  401369941
# 34   Sat, Mar 5         vs Virginia Tech  401369942

# %%
def get_schedule(team,season = '2021-22'):

  current_season = '2021-22'
  url = "https://www.espn.com/mens-college-basketball/team/schedule/_/id/"

  if team not in ids.team.unique().tolist():
    raise ValueError("Invalid Team Name")

  if season == current_season:
    team_link = ids[ids.team == team].link.item()
    team_id = str(ids[ids.team == team].id.item())
    url = url + team_id + "/" + team_link

  #else:
    #To add

 # Initial Get Request and splliting the raw HTML by gameId 
  r = requests.get(url).text
  test = r.split('gameId')

  # Cleaning and organizing resulting dataframe
  dfs = pd.read_html(url)
  df= dfs[0]
  df.columns = df.iloc[1,:].tolist()
  things_to_avoid = ['Canceled','Postponed']
  df = df[~df.RESULT.isin(things_to_avoid)]
  df = df.iloc[2:,[0,1]]
  df = df[df.DATE != 'DATE']
  df['GAME_ID'] = [test[i][1:10] for i in range(1,len(df)+1)]
  df.OPPONENT = df.OPPONENT.str.replace("*","")
  df.OPPONENT = df.OPPONENT.str.replace("\d","")
  df.OPPONENT = df.OPPONENT.str.replace('vs','')
  
  return df

# %%
get_schedule("Clemson")
# Out:
#            DATE              OPPONENT    GAME_ID
# 2    Tue, Nov 9          Presbyterian  401369925
# 3   Fri, Nov 12               Wofford  401369926
# 4   Mon, Nov 15                Bryant  401369927
# 5   Thu, Nov 18               Temple   401365886
# 6   Fri, Nov 19      St. Bonaventure   401377051
# 7   Sun, Nov 21        West Virginia   401377054
# 8   Fri, Nov 26   Charleston Southern  401369928
# 9   Tue, Nov 30             @ Rutgers  401369929
# 10   Sat, Dec 4               @ Miami  401370078
# 11  Sat, Dec 11                Drake   401369930
# 12  Tue, Dec 14            Miami (OH)  401369931
# 13  Sat, Dec 18        South Carolina  401369932
# 14  Wed, Dec 22            @ Virginia  401370045
# 16   Tue, Jan 4              Virginia  401369934
# 17   Sat, Jan 8            @ NC State  401370104
# 18  Wed, Jan 12          @ Notre Dame  401369970
# 19  Sat, Jan 15        Boston College  401369935
# 20  Tue, Jan 18            @ Syracuse  401370011
# 21  Sat, Jan 22            Pittsburgh  401369936
# 22  Tue, Jan 25               @  Duke  401369865
# 23   Wed, Feb 2         Florida State  401369937
# 24   Sat, Feb 5        @ Georgia Tech  401369905
# 25   Tue, Feb 8        North Carolina  401369938
# 26  Thu, Feb 10                  Duke  401408050
# 27  Sat, Feb 12            Notre Dame  401369939
# 28  Tue, Feb 15       @ Florida State  401369886
# 30  Sat, Feb 19          @ Louisville  401370120
# 31  Wed, Feb 23           Wake Forest  401369940
# 32  Sat, Feb 26      @ Boston College  401369923
# 33   Wed, Mar 2          Georgia Tech  401369941
# 34   Sat, Mar 5         Virginia Tech  401369942

# %%
df = get_schedule('Michigan')
df.OPPONENT = df.OPPONENT.str.replace("\d","")
df.OPPONENT = df.OPPONENT.str.replace('vs','')
df
# Out:
#            DATE            OPPONENT    GAME_ID
# 2   Wed, Nov 10             Buffalo  401364997
# 3   Sat, Nov 13   Prairie View A&M   401372133
# 4   Tue, Nov 16          Seton Hall  401372019
# 5   Sat, Nov 20               UNLV   401370151
# 6   Sun, Nov 21            Arizona   401377059
# 7   Wed, Nov 24            Tarleton  401372134
# 8    Wed, Dec 1    @ North Carolina  401369947
# 9    Sat, Dec 4     San Diego State  401372135
# 10   Tue, Dec 7          @ Nebraska  401364348
# 11  Sat, Dec 11           Minnesota  401364352
# 12  Sat, Dec 18       Southern Utah  401372136
# 14  Thu, Dec 30               @ UCF  401371947
# 15   Tue, Jan 4           @ Rutgers  401364361
# 18  Fri, Jan 14         @  Illinois  401364380
# 19  Tue, Jan 18            Maryland  401364388
# 20  Sun, Jan 23           @ Indiana  401364398
# 21  Wed, Jan 26        Northwestern  401364403
# 22  Sat, Jan 29   @  Michigan State  401364409
# 23   Tue, Feb 1            Nebraska  401364415
# 24   Sat, Feb 5           @  Purdue  401364421
# 26   Tue, Feb 8        @ Penn State  401364428
# 27  Thu, Feb 10              Purdue  401409769
# 28  Sat, Feb 12          Ohio State  401364435
# 29  Thu, Feb 17              @ Iowa  401364446
# 30  Sun, Feb 20        @  Wisconsin  401364451
# 31  Wed, Feb 23             Rutgers  401364456
# 32  Sun, Feb 27            Illinois  401364464
# 33   Tue, Mar 1      Michigan State  401412488
# 34   Thu, Mar 3                Iowa  401364472
# 35   Sun, Mar 6       @  Ohio State  401364478
