# %% [markdown]
# <a href="https://colab.research.google.com/github/fmathews11/College_Basketball_Functions/blob/main/Getting_Schedules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install kenpompy
#!pip install mechanicalsoup
import pandas as pd,numpy as np, warnings,seaborn as sns, matplotlib.pyplot as plt, requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")
from google.colab import output
output.clear()

# %%
ids = pd.read_csv('https://raw.githubusercontent.com/fmathews11/College_Basketball_Functions/main/ids.csv')

def get_schedule(team):

  current_season = '2022-23'
  url = "https://www.espn.com/mens-college-basketball/team/schedule/_/id/"

  if team not in ids.team.unique().tolist():
    raise ValueError("Invalid Team Name")

  team_link = ids[ids.team == team].link.item()
  team_id = str(ids[ids.team == team].id.item())
  url = url + team_id + "/" + team_link


 # Initial Get Request and splliting the raw HTML by gameId 
  r = requests.get(url).text
  test = r.split('gameId')

  # Cleaning and organizing resulting dataframe
  dfs = pd.read_html(url)
  df= dfs[0]
  df.columns = df.iloc[1,:].tolist()
  things_to_avoid = ['Canceled','Postponed']
  #df = df[~df.RESULT.isin(things_to_avoid)]
  df = df.iloc[2:,[0,1]]
  df = df[df.DATE != 'DATE']
  df['GAME_ID'] = [test[i][1:10] for i in range(1,len(df)+1)]
  df.OPPONENT = df.OPPONENT.str.replace("*","")
  df.OPPONENT = df.OPPONENT.str.replace("\d","")
  df.OPPONENT = df.OPPONENT.str.replace('vs','')
  
  return df

# %%
get_schedule("Purdue")
# Out:
#            DATE           OPPONENT    GAME_ID
# 2    Tue, Nov 8          Milwaukee  401483405
# 3   Fri, Nov 11        Austin Peay  401483406
# 4   Tue, Nov 15          Marquette  401479696
# 5   Thu, Nov 24     West Virginia   401483331
# 6   Fri, Nov 25           Gonzaga   401486748
# 7   Sun, Nov 27              Duke   401486751
# 9   Wed, Nov 30    @ Florida State  401479679
# 10   Sun, Dec 4          Minnesota  401484836
# 11   Wed, Dec 7            Hofstra  401483407
# 12  Sat, Dec 10         @ Nebraska  401484843
# 13  Sat, Dec 17          Davidson   401483408
# 14  Wed, Dec 21        New Orleans  401483409
# 15  Thu, Dec 29        Florida A&M  401483410
# 16   Mon, Jan 2            Rutgers  401484849
# 17   Thu, Jan 5       @ Ohio State  401484875
# 18   Sun, Jan 8        Penn State   401484880
# 19  Fri, Jan 13           Nebraska  401484890
# 20  Mon, Jan 16  @  Michigan State  401484897
# 21  Thu, Jan 19        @ Minnesota  401484904
# 22  Sun, Jan 22           Maryland  401484909
# 23  Thu, Jan 26         @ Michigan  401484917
# 24  Sun, Jan 29     Michigan State  401484924
# 25   Wed, Feb 1         Penn State  401484928
# 26   Sat, Feb 4         @  Indiana  401484932
# 27   Thu, Feb 9               Iowa  401484944
# 28  Sun, Feb 12     @ Northwestern  401484951
# 29  Thu, Feb 16        @  Maryland  401484958
# 30  Sun, Feb 19         Ohio State  401484965
# 31  Sat, Feb 25            Indiana  401484972
# 32   Thu, Mar 2        @ Wisconsin  401484985
# 33   Sun, Mar 5           Illinois  401484992
